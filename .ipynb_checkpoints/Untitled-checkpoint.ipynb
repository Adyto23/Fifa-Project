# %%
import pandas as pd
import numpy as np

import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication

from getpass import getpass  # To get the password without showing the input

# %%
password = getpass()
# Out:
# ········

# %%
#print(password)

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/bank'
engine = create_engine(connection_string)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
data = pd.read_sql_query('SELECT count(distinct(last_name)) FROM sakila.actor', engine)
data.head()
# Out:
#    count(distinct(last_name))
# 0                         121

# %%
data = pd.read_sql_query('SELECT count(distinct(last_name)) FROM sakila.actor', engine)

# %%
query2 = '''SELECT *, DATE_FORMAT(rental_date, "%%M") AS "month", DATE_FORMAT(rental_date, "%%W") AS "weekday", 
CASE
WHEN (DATE_FORMAT(rental_date, "%%W") = "Saturday") OR (DATE_FORMAT(rental_date, "%%W") = "Sunday") THEN "Weekend"
ELSE "Workday"
END AS   "day type" 
FROM SAKILA.RENTAL
LIMIT 20;''' 
result2 = engine.execute(query2)
pd.DataFrame(result2)
# Out:
#     rental_id         rental_date  inventory_id  customer_id  \
# 0           1 2005-05-24 22:53:30           367          130
# 1           2 2005-05-24 22:54:33          1525          459
# 2           3 2005-05-24 23:03:39          1711          408
# 3           4 2005-05-24 23:04:41          2452          333
# 4           5 2005-05-24 23:05:21          2079          222
# 5           6 2005-05-24 23:08:07          2792          549
# 6           7 2005-05-24 23:11:53          3995          269
# 7           8 2005-05-24 23:31:46          2346          239
# 8           9 2005-05-25 00:00:40          2580          126
# 9          10 2005-05-25 00:02:21          1824          399
# 10         11 2005-05-25 00:09:02          4443          142
# 11         12 2005-05-25 00:19:27          1584          261
# 12         13 2005-05-25 00:22:55          2294          334
# 13         14 2005-05-25 00:31:15          2701          446
# ...

# %%
query3= "SELECT title FROM sakila.film WHERE title LIKE '%%ARMAGEDDON%%'"
result3 = engine.execute(query3)
pd.DataFrame(result3)
# Out:
#                    title
# 0        ARMAGEDDON LOST
# 1    LADYBUGS ARMAGEDDON
# 2       METAL ARMAGEDDON
# 3    MOSQUITO ARMAGEDDON
# 4  STAGECOACH ARMAGEDDON
# 5      STEERS ARMAGEDDON

# %%
query3= "SELECT * FROM sakila.film ORDER BY length DESC"
result3 = engine.execute(query3)
pd.DataFrame(result3)
# Out:
#      film_id                title  \
# 0        141        CHICAGO NORTH
# 1        182       CONTROL ANTHEM
# 2        212       DARN FORRESTER
# 3        349          GANGS PRIDE
# 4        426            HOME PITY
# ..       ...                  ...
# 995       15         ALIEN CENTER
# 996      469            IRON MOON
# 997      504        KWAI HOMEWARD
# 998      505     LABYRINTH LEAGUE
# 999      730  RIDGEMONT SUBMARINE
#
#                                            description  release_year  \
# 0    A Fateful Yarn of a Mad Cow And a Waitress who...          2006
# 1    A Fateful Documentary of a Robot And a Student...          2006
# 2    A Fateful Story of a A Shark And a Explorer wh...          2006
# 3    A Taut Character Study of a Woman And a A Shar...          2006
# 4    A Touching Panorama of a Man And a Secret Agen...          2006
# ..                                                 ...           ...
# ...

# %%
query3= "SELECT * FROM sakila.film WHERE special_features LIKE '%%Behind the Scenes%%'"
result3 = engine.execute(query3)
pd.DataFrame(result3)
# Out:
#      film_id             title  \
# 0          1  ACADEMY DINOSAUR
# 1          4  AFFAIR PREJUDICE
# 2         11   ALAMO VIDEOTAPE
# 3         13       ALI FOREVER
# 4         14    ALICE FANTASIA
# ..       ...               ...
# 533      991      WORST BANGER
# 534      993    WRONG BEHAVIOR
# 535      996    YOUNG LANGUAGE
# 536      997        YOUTH KICK
# 537     1000         ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 2    A Boring Epistle of a Butler And a Cat who mus...          2006
# 3    A Action-Packed Drama of a Dentist And a Croco...          2006
# 4    A Emotional Drama of a A Shark And a Database ...          2006
# ..                                                 ...           ...
# 533  A Thrilling Drama of a Madman And a Dentist wh...          2006
# ...

# %%
query6= "select distinct(rating), round(avg(length),2) from sakila.film group by rating having  round(avg(length),2)>120"
result6 = engine.execute(query6)
pd.DataFrame(result6)
# Out:
#   rating round(avg(length),2)
# 0  PG-13               120.44

# %%
query7= "select title , length , RANK() OVER(ORDER BY length DESC) as ranking from sakila.film"
result7 = engine.execute(query7)
pd.DataFrame(result7)
# Out:
#                    title  length  ranking
# 0          CHICAGO NORTH     185        1
# 1         CONTROL ANTHEM     185        1
# 2         DARN FORRESTER     185        1
# 3            GANGS PRIDE     185        1
# 4              HOME PITY     185        1
# ..                   ...     ...      ...
# 995         ALIEN CENTER      46      996
# 996            IRON MOON      46      996
# 997        KWAI HOMEWARD      46      996
# 998     LABYRINTH LEAGUE      46      996
# 999  RIDGEMONT SUBMARINE      46      996
#
# [1000 rows x 3 columns]
